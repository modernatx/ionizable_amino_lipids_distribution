# %%
import numpy as np
import math  as m
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
from matplotlib import rc
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
rc('text', usetex=True)
mpl.rcParams['axes.linewidth'] = 2
mpl.rcParams.update({'figure.autolayout': True})

INPUT1    =  open("order_parameter_10.txt" , "r")
INPUT2    =  open("order_parameter_20.txt" , "r")
INPUT3    =  open("order_parameter_30.txt" , "r")
INPUT4    =  open("order_parameter_40.txt" , "r")
INPUT5    =  open("order_parameter_50.txt" , "r")
INPUT6    =  open("order_parameter_10-p.txt" , "r")
INPUT7    =  open("order_parameter_20-p.txt" , "r")
INPUT8    =  open("order_parameter_30-p.txt" , "r")
INPUT9    =  open("order_parameter_40-p.txt" , "r")
INPUT10   =  open("order_parameter_50-p.txt" , "r")
INPUT11   =  open("order_parameter_10-n.txt" , "r")
INPUT12   =  open("order_parameter_20-n.txt" , "r")
INPUT13   =  open("order_parameter_30-n.txt" , "r")
INPUT14   =  open("order_parameter_40-n.txt" , "r")
INPUT15   =  open("order_parameter_50-n.txt" , "r")
INPUT16   =  open("../order_parameter_dspc/order_parameter_10.txt" , "r")
INPUT17   =  open("../order_parameter_dspc/order_parameter_20.txt" , "r")
INPUT18   =  open("../order_parameter_dspc/order_parameter_30.txt" , "r")
INPUT19   =  open("../order_parameter_dspc/order_parameter_40.txt" , "r")
INPUT20   =  open("../order_parameter_dspc/order_parameter_50.txt" , "r")

# %%
lines1     = INPUT1.readlines()
lines2     = INPUT2.readlines()
lines3     = INPUT3.readlines()
lines4     = INPUT4.readlines()
lines5     = INPUT5.readlines()
lines6     = INPUT6.readlines()
lines7     = INPUT7.readlines()
lines8     = INPUT8.readlines()
lines9     = INPUT9.readlines()
lines10    = INPUT10.readlines()
lines11    = INPUT11.readlines()
lines12    = INPUT12.readlines()
lines13    = INPUT13.readlines()
lines14    = INPUT14.readlines()
lines15    = INPUT15.readlines()
lines16    = INPUT16.readlines()
lines17    = INPUT17.readlines()
lines18    = INPUT18.readlines()
lines19    = INPUT19.readlines()
lines20    = INPUT20.readlines()

t1  = np.array([])
t2  = np.array([])
t3  = np.array([])
t4  = np.array([])
t5  = np.array([])
t6  = np.array([])
t7  = np.array([])
t8  = np.array([])
t9  = np.array([])
t10 = np.array([])
t11 = np.array([])
t12 = np.array([])
t13 = np.array([])
t14 = np.array([])
t15 = np.array([])
t16 = np.array([])
t17 = np.array([])
t18 = np.array([])
t19 = np.array([])
t20 = np.array([])

for i in range(int(len(lines1) * 0.5), int(len(lines1))):
    line = lines1[i].split()
    t1    = (np.append(t1, float(line[0])))

for i in range(int(len(lines2) * 0.5), int(len(lines2))):
    line = lines2[i].split()
    t2    = (np.append(t2, float(line[0])))

for i in range(int(len(lines3) * 0.5), int(len(lines3))):
    line = lines3[i].split()
    t3    = (np.append(t3, float(line[0])))

for i in range(int(len(lines4) * 0.5), int(len(lines4))):
    line = lines4[i].split()
    t4    = (np.append(t4, float(line[0])))

for i in range(int(len(lines5) * 0.5), int(len(lines5))):
    line = lines5[i].split()
    t5    = (np.append(t5, float(line[0])))

for i in range(int(len(lines6) * 0.5), int(len(lines6))):
    line = lines6[i].split()
    t6    = (np.append(t6, float(line[0])))

for i in range(int(len(lines7) * 0.5), int(len(lines7))):
    line = lines7[i].split()
    t7    = (np.append(t7, float(line[0])))

for i in range(int(len(lines8) * 0.5), int(len(lines8))):
    line = lines8[i].split()
    t8    = (np.append(t8, float(line[0])))

for i in range(int(len(lines9) * 0.5), int(len(lines9))):
    line = lines9[i].split()
    t9    = (np.append(t9, float(line[0])))

for i in range(int(len(lines10) * 0.5), int(len(lines10))):
    line = lines10[i].split()
    t10    = (np.append(t10, float(line[0])))

for i in range(int(len(lines11) * 0.5), int(len(lines11))):
    line = lines11[i].split()
    t11    = (np.append(t11, float(line[0])))

for i in range(int(len(lines12) * 0.5), int(len(lines12))):
    line = lines12[i].split()
    t12    = (np.append(t12, float(line[0])))

for i in range(int(len(lines13) * 0.5), int(len(lines13))):
    line = lines13[i].split()
    t13    = (np.append(t13, float(line[0])))

for i in range(int(len(lines14) * 0.5), int(len(lines14))):
    line = lines14[i].split()
    t14    = (np.append(t14, float(line[0])))

for i in range(int(len(lines15) * 0.5), int(len(lines15))):
    line = lines15[i].split()
    t15    = (np.append(t15, float(line[0])))

for i in range(int(len(lines16) * 0.5), int(len(lines16))):
    line = lines16[i].split()
    t16    = (np.append(t16, float(line[0])))

for i in range(int(len(lines17) * 0.5), int(len(lines17))):
    line = lines17[i].split()
    t17    = (np.append(t17, float(line[0])))

for i in range(int(len(lines18) * 0.5), int(len(lines18))):
    line = lines18[i].split()
    t18    = (np.append(t18, float(line[0])))

for i in range(int(len(lines19) * 0.5), int(len(lines19))):
    line = lines19[i].split()
    t19    = (np.append(t19, float(line[0])))

for i in range(int(len(lines20) * 0.5), int(len(lines20))):
    line = lines20[i].split()
    t20    = (np.append(t20, float(line[0])))
print (np.mean(t1))
print (np.mean(t5))
# Out:
# 1.2397991898919347
# 0.4691802578281761

# %%
plt.errorbar(10, 0.5 * np.mean(t1), yerr= 0.5 * np.std(t1), uplims = 0.5 * (np.mean(t1) + np.std(t1)), lolims = 0.5 * (np.mean(t1) - np.std(t1)),
             marker = 'o', markersize=20, mfc = 'yellow', mec = 'gold', mew = 2,  label='$\mathrm{Overall}$', color = 'gold')
plt.errorbar(20, 0.5 * np.mean(t2), yerr= 0.5 * np.std(t2), uplims = 0.5 * (np.mean(t2) + np.std(t2)), lolims = 0.5 * (np.mean(t2) - np.std(t2)),
             marker = 'o', markersize=20, mfc = 'yellow', mec = 'gold', mew = 2)
plt.errorbar(30, 0.5 * np.mean(t3), yerr= 0.5 * np.std(t3), uplims = 0.5 * (np.mean(t3) + np.std(t3)), lolims = 0.5 * (np.mean(t3) - np.std(t3)),
             marker = 'o', markersize=20, mfc = 'yellow', mec = 'gold', mew = 2)
plt.errorbar(40, 0.5 * np.mean(t4), yerr= 0.5 * np.std(t4), uplims = 0.5 * (np.mean(t4) + np.std(t4)), lolims = 0.5 * (np.mean(t4) - np.std(t4)),
             marker = 'o', markersize=20, mfc = 'yellow', mec = 'gold', mew = 2)
plt.errorbar(50, 0.5 * np.mean(t5), yerr= 0.5 * np.std(t5), uplims = 0.5 * (np.mean(t5) + np.std(t5)), lolims = 0.5 * (np.mean(t5) - np.std(t5)),
             marker = 'o', markersize=20, mfc = 'yellow', mec = 'gold', mew = 2)
print (0.5 * np.mean(t1))
print (0.5 * np.mean(t2))
print (0.5 * np.mean(t3))
print (0.5 * np.mean(t4))
print (0.5 * np.mean(t5))
print ('-------------------')
plt.errorbar(10, 0.5 * np.mean(t6), yerr= 0.5 * np.std(t6), uplims = 0.5 * (np.mean(t6) + np.std(t6)), lolims = 0.5 * (np.mean(t6) - np.std(t6)),
             marker = 'o', markersize=20, mfc = 'salmon', mec = 'red', mew = 2, label='$\mathrm{Protonated}$', color = 'red')
plt.errorbar(20, 0.5 * np.mean(t7), yerr= 0.5 * np.std(t7), uplims = 0.5 * (np.mean(t7) + np.std(t7)), lolims = 0.5 * (np.mean(t7) - np.std(t7)),
             marker = 'o', markersize=20, mfc = 'salmon', mec = 'red', mew = 2)
plt.errorbar(30, 0.5 * np.mean(t8), yerr= 0.5 * np.std(t8), uplims = 0.5 * (np.mean(t8) + np.std(t8)), lolims = 0.5 * (np.mean(t8) - np.std(t8)),
             marker = 'o', markersize=20, mfc = 'salmon', mec = 'red', mew = 2)
plt.errorbar(40, 0.5 * np.mean(t9), yerr= 0.5 * np.std(t9), uplims = 0.5 * (np.mean(t9) + np.std(t9)), lolims = 0.5 * (np.mean(t9) - np.std(t9)),
             marker = 'o', markersize=20, mfc = 'salmon', mec = 'red', mew = 2)
plt.errorbar(50, 0.5 * np.mean(t10), yerr= 0.5 * np.std(t10), uplims = 0.5 * (np.mean(t10) + np.std(t10)), lolims = 0.5 * (np.mean(t10) - np.std(t10)),
             marker = 'o', markersize=20, mfc = 'salmon', mec = 'red', mew = 2)
print (0.5 * np.mean(t6))
print (0.5 * np.mean(t7))
print (0.5 * np.mean(t8))
print (0.5 * np.mean(t9))
print (0.5 * np.mean(t10))
print ('-------------------')

plt.errorbar(10, 0.5 * np.mean(t11), yerr= 0.5 * np.std(t11), uplims = 0.5 * (np.mean(t11) + np.std(t11)), lolims = 0.5 * (np.mean(t11) - np.std(t11)),
             marker = 'o', markersize=20, mfc = 'cyan', mec = 'blue', mew = 2, label='$\mathrm{Neutral}$', color = 'blue')
plt.errorbar(20, 0.5 * np.mean(t12), yerr= 0.5 * np.std(t12), uplims = 0.5 * (np.mean(t12) + np.std(t12)), lolims = 0.5 * (np.mean(t12) - np.std(t12)),
             marker = 'o', markersize=20, mfc = 'cyan', mec = 'blue', mew = 2)
plt.errorbar(30, 0.5 * np.mean(t13), yerr= 0.5 * np.std(t13), uplims = 0.5 * (np.mean(t13) + np.std(t13)), lolims = 0.5 * (np.mean(t13) - np.std(t13)),
             marker = 'o', markersize=20, mfc = 'cyan', mec = 'blue', mew = 2)
plt.errorbar(40, 0.5 * np.mean(t14), yerr= 0.5 * np.std(t14), uplims = 0.5 * (np.mean(t14) + np.std(t14)), lolims = 0.5 * (np.mean(t14) - np.std(t14)),
             marker = 'o', markersize=20, mfc = 'cyan', mec = 'blue', mew = 2)
plt.errorbar(50, 0.5 * np.mean(t15), yerr= 0.5 * np.std(t15), uplims = 0.5 * (np.mean(t15) + np.std(t15)), lolims = 0.5 * (np.mean(t15) - np.std(t15)),
             marker = 'o', markersize=20, mfc = 'cyan', mec = 'blue', mew = 2)
print (0.5 * np.mean(t11))
print (0.5 * np.mean(t12))
print (0.5 * np.mean(t13))
print (0.5 * np.mean(t14))
print (0.5 * np.mean(t15))

#     #y = mlab.normpdf(bins, mu, sigma)
#     print (i)
plt.ylabel('$ \mathrm{Tilt \ angle \ cosine}$', fontsize=25)
plt.xlabel('$\mathrm{Lipid-5 \ \%}$',fontsize=25)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
plt.xlim((5, 55))
plt.ylim((-0.05, 1))
#plt.yticks(np.arange(0.246, 0.258, step=0.004))
#plt.xticks(np.arange(10, 51, step=10))
plt.legend(fontsize=15)
plt.savefig("order_parameter_SM86.png")
plt.savefig("order_parameter_SM86.pdf")

# plt.close()
# Out:
# 0.6198995949459674
# 0.4677151272353407
# 0.364940391004551
# 0.2823124544812945
# 0.23459012891408804
# -------------------
# 0.7980830042494499
# 0.6885399762134248
# 0.6266711398536519
# 0.508647040468453
# 0.45532963868314996
# -------------------
# 0.4417161856424849
# 0.24689027825725654
# 0.10320964215545032
# 0.05597786849413596
# 0.013850619145026112
